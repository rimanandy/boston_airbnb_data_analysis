# %%
#importing files
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
import pandas as pd

# %%
#Reading CSV files
calender = pd.read_csv("calendar.csv")
listings = pd.read_csv("listings (1).csv")
reviews = pd.read_csv("reviews.csv")

# %%
#Exploring the listings dataset
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   scrape_id                         3585 non-null   int64
#  3   last_scraped                      3585 non-null   object
#  4   name                              3585 non-null   object
#  5   summary                           3442 non-null   object
#  6   space                             2528 non-null   object
#  7   description                       3585 non-null   object
#  8   experiences_offered               3585 non-null   object
#  9   neighborhood_overview             2170 non-null   object
#  10  notes                             1610 non-null   object
# ...

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.585000e+03  3.585000e+03  3.585000e+03          3585.000000
# mean   8.440875e+06  2.016091e+13  2.492311e+07            58.902371
# std    4.500787e+06  0.000000e+00  2.292781e+07           171.119663
# min    3.353000e+03  2.016091e+13  4.240000e+03             0.000000
# 25%    4.679319e+06  2.016091e+13  6.103425e+06             1.000000
# 50%    8.577620e+06  2.016091e+13  1.928100e+07             2.000000
# 75%    1.278953e+07  2.016091e+13  3.622147e+07             7.000000
# max    1.493346e+07  2.016091e+13  9.385411e+07           749.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                3585.000000                           0.0  3585.000000
# mean                   58.902371                           NaN    42.340032
# std                   171.119663                           NaN     0.024403
# ...

# %%
# dropping values which has NaN
listings.dropna(subset=["review_scores_rating", "price", "review_scores_value", "neighbourhood", 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'property_type'], axis = 0, inplace = True)

# %%
listings.sample(5)
# Out:
#            id                           listing_url       scrape_id  \
# 1487  6213822  https://www.airbnb.com/rooms/6213822  20160906204935
# 3314  1839549  https://www.airbnb.com/rooms/1839549  20160906204935
# 787    349347   https://www.airbnb.com/rooms/349347  20160906204935
# 1482  8737466  https://www.airbnb.com/rooms/8737466  20160906204935
# 3170  4287366  https://www.airbnb.com/rooms/4287366  20160906204935
#
#      last_scraped                                 name  \
# 1487   2016-09-07       In the Back Bay of Boston! GS2
# 3314   2016-09-07   a*SUNNY BRIGHT & COZY ROOM BOSTON*
# 787    2016-09-07  Modern Studio Apartment - South End
# 1482   2016-09-07      Elegant studio, heart of Boston
# 3170   2016-09-07      Sunny 2 Bedroom in South Boston
#
#                                                 summary  \
# 1487  Garrison Square is a beautiful property in Bos...
# 3314  This room makes spring feel like its already h...
# ...

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
listings.sample(2)
# Out:
#             id                            listing_url       scrape_id  \
# 2941   3250739   https://www.airbnb.com/rooms/3250739  20160906204935
# 2150  11866651  https://www.airbnb.com/rooms/11866651  20160906204935
#
#      last_scraped                                              name  \
# 2941   2016-09-07                Umass,City,MGH,Longwood(BI,BWH)(D)
# 2150   2016-09-07  3 BR|2.5 BA Renovated House Parking Top Location
#
#                                                 summary  \
# 2941  Welcome to our international home, we have hos...
# 2150  Boston's Best Location! 2016 remodel of gorgeo...
#
#                                                   space  \
# 2941  Best location, close to everything. Available ...
# 2150  Our home is a 3-story brownstone painstakingly...
#
#                                             description experiences_offered  \
# 2941  Welcome to our international home, we have hos...                none
# ...

# %%
#Wrangling and cleaning data
# choosing columns which are important to us in this project
cols = ['id', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'property_type', 'accommodates', 'bathrooms', 'beds', 'price', 'review_scores_value', 'review_scores_rating', 'review_scores_cleanliness', 'review_scores_communication', 'review_scores_location', 'neighbourhood']

# %%
listings = listings[cols]
listings.head()
# Out:
#          id  host_response_time host_response_rate host_acceptance_rate  \
# 1   3075044      within an hour               100%                 100%
# 2      6976  within a few hours               100%                  88%
# 4   7651065      within an hour               100%                 100%
# 5  12386020  within a few hours               100%                  95%
# 7   2843445  within a few hours               100%                 100%
#
#   property_type  accommodates  bathrooms  beds   price  review_scores_value  \
# 1     Apartment             2        1.0   1.0  $65.00                  9.0
# 2     Apartment             2        1.0   1.0  $65.00                 10.0
# 4         House             2        1.5   2.0  $79.00                 10.0
# 5   Condominium             2        1.0   1.0  $75.00                 10.0
# 7         House             2        2.0   1.0  $75.00                 10.0
#
#    review_scores_rating  review_scores_cleanliness  \
# ...

# %%
wrangle_prices = lambda x : (x.replace('.00','').replace('$','').replace(',',''))
listings['price']=listings['price'].apply(wrangle_prices)
listings['price'] = pd.to_numeric(listings['price'])
# converting the prices to numeric value
listings.head()
# Out:
#          id  host_response_time host_response_rate host_acceptance_rate  \
# 1   3075044      within an hour               100%                 100%
# 2      6976  within a few hours               100%                  88%
# 4   7651065      within an hour               100%                 100%
# 5  12386020  within a few hours               100%                  95%
# 7   2843445  within a few hours               100%                 100%
#
#   property_type  accommodates  bathrooms  beds  price  review_scores_value  \
# 1     Apartment             2        1.0   1.0     65                  9.0
# 2     Apartment             2        1.0   1.0     65                 10.0
# 4         House             2        1.5   2.0     79                 10.0
# 5   Condominium             2        1.0   1.0     75                 10.0
# 7         House             2        2.0   1.0     75                 10.0
#
#    review_scores_rating  review_scores_cleanliness  \
# ...

# %%
# removing % sign and converting host_response_rate to numeric
wrangle_data = lambda x : (x.replace('%',''))
listings['host_response_rate']=listings['host_response_rate'].apply(wrangle_data)
listings['host_response_rate'] = pd.to_numeric(listings['host_response_rate'])
listings['host_response_rate'].head()
# Out:
# 1    100
# 2    100
# 4    100
# 5    100
# 7    100
# Name: host_response_rate, dtype: int64

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2160 entries, 1 to 3583
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           2160 non-null   int64
#  1   host_response_time           2160 non-null   object
#  2   host_response_rate           2160 non-null   int64
#  3   host_acceptance_rate         2160 non-null   object
#  4   property_type                2160 non-null   object
#  5   accommodates                 2160 non-null   int64
#  6   bathrooms                    2150 non-null   float64
#  7   beds                         2158 non-null   float64
#  8   price                        2160 non-null   int64
#  9   review_scores_value          2160 non-null   float64
#  10  review_scores_rating         2160 non-null   float64
#  11  review_scores_cleanliness    2159 non-null   float64
#  12  review_scores_communication  2159 non-null   float64
# ...

# %%
#plotting a histgram to quickly visualise the data
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
listings.hist(ax = ax);
# Out:
# C:\Users\RIMA\AppData\Local\Temp\ipykernel_6644\602934967.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   listings.hist(ax = ax);

# %%
#Wrangling and Cleaning Calendar Data
calender.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
calender.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
calender.price.isnull().sum()/calender.shape[0]
# Out:
# 0.5087157820748879

# %%
calender.dropna(subset=['price'],axis=0,inplace=True)
calender.price.astype(str)
calender['date']= pd.to_datetime(calender['date'])

# %%
wrangle_prices = lambda x : (x.replace('.00','').replace('$','').replace(',',''))
calender.price=calender.price.apply(wrangle_prices)
calender['price'].head()
# Out:
# 365    65
# 366    65
# 367    65
# 368    75
# 369    75
# Name: price, dtype: object

# %%
calender.head()
# Out:
#      listing_id       date available price
# 365     3075044 2017-08-22         t    65
# 366     3075044 2017-08-21         t    65
# 367     3075044 2017-08-20         t    65
# 368     3075044 2017-08-19         t    75
# 369     3075044 2017-08-18         t    75

# %%
calender['listing_id'] =calender['listing_id'].astype(str)

# %%
calender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 643037 entries, 365 to 1308879
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  643037 non-null  object
#  1   date        643037 non-null  datetime64[ns]
#  2   available   643037 non-null  object
#  3   price       643037 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 24.5+ MB

# %%
calender.describe()
# Out:
#                                 date
# count                         643037
# mean   2017-03-11 12:08:31.987957760
# min              2016-09-06 00:00:00
# 25%              2016-12-16 00:00:00
# 50%              2017-03-06 00:00:00
# 75%              2017-06-07 00:00:00
# max              2017-09-05 00:00:00

# %%
#Wrangling and Cleaning Reviews Dataset
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     68275 non-null  int64
#  1   id             68275 non-null  int64
#  2   date           68275 non-null  object
#  3   reviewer_id    68275 non-null  int64
#  4   reviewer_name  68275 non-null  object
#  5   comments       68222 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 3.1+ MB

# %%
reviews.describe()
# Out:
#          listing_id            id   reviewer_id
# count  6.827500e+04  6.827500e+04  6.827500e+04
# mean   4.759910e+06  5.246516e+07  2.802389e+07
# std    3.788990e+06  2.790991e+07  2.234097e+07
# min    3.353000e+03  1.021000e+03  1.430000e+02
# 25%    1.458081e+06  3.010420e+07  9.001346e+06
# 50%    4.080000e+06  5.223121e+07  2.305179e+07
# 75%    7.377034e+06  7.663248e+07  4.213454e+07
# max    1.484378e+07  9.999045e+07  9.335034e+07

# %%
#Data Analysis and main highlights
#Since all data that will be used further is cleaned, transformed and imputed, now we are ready to proceed to the next steps, visualising our data, comparing the data, and do everything to help answer our business questions. Once all questions are answered that do not require ML algorithms here, we will proceed to answer the questions that need prediction techhniques.

# %%
#Q1. How well are property and prices related?

# %%
features_df = listings.copy()

# %%
# checking if the target label has all entries recorded
features_df.price.count()
# Out:
# 2160

# %%
features_df.shape
# Out:
# (2160, 15)

# %%
# categorizing number of listings with property type
property_type_count = features_df.property_type.value_counts()

# %%
property_type_count
# Out:
# property_type
# Apartment          1514
# House               378
# Condominium         153
# Townhouse            43
# Bed & Breakfast      25
# Loft                 24
# Boat                  9
# Other                 8
# Villa                 2
# Dorm                  2
# Guesthouse            1
# Entire Floor          1
# Name: count, dtype: int64

# %%
property_type_count.plot.bar(color = 'teal', figsize =(10,5), title = 'Boston Property Type Frequency')
plt.xlabel('Property type');
plt.ylabel('Number of listings');

# %%
price_per_property_type = features_df.groupby('property_type').price.mean()

# %%
price_per_property_type
# Out:
# property_type
# Apartment          179.042272
# Bed & Breakfast    113.320000
# Boat               266.333333
# Condominium        188.823529
# Dorm                62.500000
# Entire Floor        80.000000
# Guesthouse         289.000000
# House              134.201058
# Loft               204.125000
# Other              172.750000
# Townhouse          154.023256
# Villa              140.000000
# Name: price, dtype: float64

# %%
# plot a graph that depicts a relation between property type and price
plt.figure(figsize=(10,5));
price_per_property_type.plot(kind='bar', color='teal');
plt.xlabel('Property Types')
plt.ylabel('Average Price')
plt.title('Property vs Average Price Chart');

# %%
#Conclusions:
#Airbnb has more apartments listings followed by Bed and Breakfast.
#The property type is largely dependent on the price.
# Guesthouse property type has the highest price followed by Boat and Loft.

# %%
listings.columns
# Out:
# Index(['id', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'property_type', 'accommodates', 'bathrooms',
#        'beds', 'price', 'review_scores_value', 'review_scores_rating',
#        'review_scores_cleanliness', 'review_scores_communication',
#        'review_scores_location', 'neighbourhood'],
#       dtype='object')

# %%
#Q2. Where to invest in a property in Boston to get the maximum number of returns from Airbnb?

# %%
price_per_neighbourhood = features_df.groupby('neighbourhood').price.mean()

# %%
price_per_neighbourhood
# Out:
# neighbourhood
# Allston-Brighton      114.681614
# Back Bay              235.950739
# Beacon Hill           213.503401
# Brookline              64.000000
# Cambridge             254.500000
# Charlestown           193.803571
# Chestnut Hill          71.500000
# Chinatown             247.266667
# Dorchester             96.431250
# Downtown              183.571429
# Downtown Crossing     273.190476
# East Boston           124.100000
# Fenway/Kenmore        194.210884
# Financial District    330.000000
# Government Center     205.333333
# Hyde Park             107.333333
# Jamaica Plain         140.647773
# Leather District      272.000000
# Mattapan               59.000000
# Mission Hill          111.750000
# North End             193.688172
# Roslindale             93.866667
# Roxbury               143.033333
# Somerville             71.428571
# South Boston          210.676829
# South End             212.331839
# Theater District      211.550000
# West End              234.441176
# ...

# %%
# plot a graph that depicts a relation between neighbourhood and price
plt.figure(figsize=(15,8));
price_per_neighbourhood.plot(kind='bar', color='teal');
plt.xlabel('Neighbourhoods')
plt.ylabel('Average Price')
plt.title('Neighbourhood vs Average Price Chart');

# %%
#Conclusions:
#Investing a property in the financial district will provide the highest returns followed by Downtown Crossing and Leather District.

# %%
#How well can we predict reviews and what aspects correlate with reviews?

# %%
features_df.review_scores_rating.unique()
# Out:
# array([ 94.,  98.,  99., 100.,  96.,  80.,  97.,  91.,  95.,  90.,  92.,
#         87.,  93.,  73.,  82.,  88.,  89.,  81.,  78.,  74.,  86.,  85.,
#         75.,  79.,  70.,  83.,  84.,  60.,  40.,  68.,  67.,  48.,  76.,
#         71.,  65.,  53.,  47.,  72.,  64.,  77.,  46.,  50.,  69.,  55.,
#         66.,  20.])

# %%
ratings_per_neighbourhood = features_df.groupby(
    ['neighbourhood', 'property_type']).review_scores_rating.mean()

# %%
ratings_per_neighbourhood.sort_values(ascending=False)
# Out:
# neighbourhood       property_type
# Financial District  Villa              100.0
# Back Bay            Other              100.0
# Mission Hill        Loft               100.0
# North End           Loft               100.0
# Allston-Brighton    Loft               100.0
#                                        ...
# Somerville          Apartment           82.5
# Mattapan            Apartment           81.0
# Beacon Hill         Townhouse           80.0
# Cambridge           Apartment           74.5
# Downtown            Bed & Breakfast     64.0
# Name: review_scores_rating, Length: 110, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x='neighbourhood', y='property_type', hue='review_scores_rating', data=features_df);
plt.xticks(rotation=90);
plt.title('Reviews based on neighbourhood and price');

# %%
ratings_per_property_type = features_df.groupby('property_type').review_scores_rating.mean()
ratings_per_property_type
# Out:
# property_type
# Apartment           91.671731
# Bed & Breakfast     92.760000
# Boat                90.666667
# Condominium         94.522876
# Dorm                86.500000
# Entire Floor       100.000000
# Guesthouse         100.000000
# House               92.835979
# Loft                96.375000
# Other               86.625000
# Townhouse           94.604651
# Villa               99.500000
# Name: review_scores_rating, dtype: float64

# %%
ratings_per_property_type.plot(kind='bar',color='teal');
plt.xlabel('Property types')
plt.ylabel('Average rating score')
plt.title('Property Type vs Average Rating Chart');

# %%
ratings_per_bedrooms = features_df.groupby(['property_type', 'beds']).review_scores_rating.mean()

# %%
ratings_per_bedrooms
# Out:
# property_type    beds
# Apartment        0.0      89.500000
#                  1.0      91.833518
#                  2.0      91.043062
#                  3.0      91.629921
#                  4.0      92.883721
#                  5.0      94.363636
#                  6.0      92.250000
#                  7.0      97.333333
#                  8.0     100.000000
#                  9.0     100.000000
#                  16.0     93.000000
# Bed & Breakfast  1.0      94.388889
#                  2.0      88.571429
# Boat             1.0     100.000000
#                  2.0      95.000000
#                  3.0      90.000000
#                  4.0      89.500000
#                  5.0      79.000000
#                  6.0      94.000000
# Condominium      0.0      80.000000
#                  1.0      94.827160
#                  2.0      95.166667
#                  3.0      93.571429
#                  4.0      94.600000
#                  5.0      85.333333
# ...

# %%
plt.figure(figsize=(15, 5))
ratings_per_bedrooms.plot(kind='bar',color='teal');
plt.xlabel('Property type with number of bedrooms')
plt.ylabel('Average Rating Score')
plt.title('Property_type, Bedrooms vs Average Rating Chart');

# %%
ratings_per_bathrooms = features_df.groupby(['property_type', 'bathrooms']).review_scores_rating.mean()
ratings_per_bathrooms
# Out:
# property_type    bathrooms
# Apartment        0.0           91.714286
#                  0.5           82.666667
#                  1.0           91.717806
#                  1.5           91.617021
#                  2.0           91.612360
#                  2.5           96.833333
#                  3.0           86.777778
#                  4.0           98.000000
# Bed & Breakfast  1.0           91.777778
#                  1.5           98.000000
#                  2.0           95.000000
#                  2.5           98.000000
# Boat             1.0           90.800000
#                  1.5           86.500000
#                  2.0           94.500000
# Condominium      1.0           94.592920
#                  1.5           95.454545
#                  2.0           93.518519
#                  2.5           99.000000
# Dorm             1.0           86.500000
# Entire Floor     1.0          100.000000
# Guesthouse       1.0          100.000000
# ...

# %%
plt.figure(figsize=(15, 5))
ratings_per_bathrooms.plot(kind='bar',color='teal');
plt.xlabel('Property type with number of bathrooms')
plt.ylabel('Average Rating Score')
plt.title('Property_type, Bathrooms vs Average Rating Chart');

# %%
#Conclusion
#From the data it is obvious that people enjoy living in Guesthouses, Entire Floor and Boats  depending on their interests and budgets.

#There seems to be Guesthouse with only 2 bedrooms and 1 bathroom in listings data and these are likely to get the highest review score. People are also comfortable with Villas with 2 bathrooms and 2 bedrooms . 
#However, they are not quite satisfied with Bed and Breakfast's experiences as they have got the least review score.
#Again, guesthouse takes the first place along with entire floow with at least one bathroom and villas with two.
